# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
pp = "C:\\Users\\THOMA\\Documents\\Computer Science and Math\\EIT UCA\\Deep Learning\\kaggle"
import os
for dirname, _, filenames in os.walk(pp+'\\data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# a little helper function do directly display a Tensor
def display_tensor(t):
  trans = transforms.ToPILImage()
  display(trans(t))
# Out:
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\0.jpg
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\1.jpg
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\10.jpg
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\100.jpg
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\1000.jpg
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\1001.jpg
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\1002.jpg
# C:\Users\THOMA\Documents\Computer Science and Math\EIT UCA\Deep Learning\kaggle\data\kaggle_evaluation\1003.jpg
# ...

# %%
import torch
import torch.nn as nn

#We will need torchvision transforms for data augmentation
from torchvision import transforms
from PIL import Image

# library to do bash-like wildcard expansion
import glob
import matplotlib.pyplot as plt
# others
import numpy as np
import random
import matplotlib.image as mpimg
from PIL import Image
from IPython.display import display
from tqdm import tqdm_notebook
from os import listdir
from os.path import isfile, join
import random
path = "/data"
training_path = [f.split("_") for f in listdir(pp+"\\data\\training")]
validation_path = [f.split("_") for f in listdir(pp+"\\data\\validation")]
kaggle_evaluation = [f for f in listdir(pp+"\\data\\kaggle_evaluation")]

tmp_name , tmp_classes = [t[0]+"_"+t[1] for t in training_path] , [t[0] for t in training_path]
dataframe_train = pd.DataFrame(list(zip(tmp_name,tmp_classes)))
dataframe_train.columns = ["filename","label"]

tmp_name , tmp_classes = [t[0]+"_"+t[1] for t in validation_path] , [t[0] for t in validation_path]
dataframe_val = pd.DataFrame(list(zip(tmp_name,tmp_classes)))
dataframe_val.columns = ["filename","label"]

tmp_name , tmp_classes = [t[0]+"_"+t[1] for t in kaggle_evaluation] , [t[0] for t in kaggle_evaluation]
dataframe_eval = pd.DataFrame(list(zip(tmp_name,tmp_classes)))
dataframe_eval.columns = ["filename","label"]

print(dataframe_train)
print(dataframe_val)
print(dataframe_eval)


train_set = {}
val_set = {}
print("number of image in training ",len(training_path))
print("number of image in validation ",len(validation_path))

for image in training_path:
    if image[0] in train_set:
        train_set[image[0]].append(image[1][:-4])
    else:
        train_set[image[0]] = [image[1][:-4]]

for image in validation_path:
    if image[0] in val_set:
        val_set[image[0]].append(image[1][:-4])
    else:
        val_set[image[0]] = [image[1][:-4]]    
       
for i in range(11):
    print("train classe : ",i , "nombre d'images : ",len(train_set[str(i)]))
for i in range(11):
    print("val classe : ",i , "nombre d'images : ",len(val_set[str(i)]))


#!ls /kaggle/input/polytech-ds-2019/polytech-ds-2019/training
#fig, axes = plt.subplots(11,11,figsize=(30,30))

#for i in range(11):    
  #for j in range(11):
   # choices = train_set[str(i)]
    #mage = random.choice(choices)
    #img=Image.open("/kaggle/input/polytech-ds-2019/polytech-ds-2019/"+"training"+"/"+str(i) +"_"+mage+".jpg")
    #axes[i,j].imshow(np.asarray(img))
# Out:
#        filename label
# 0       0_0.jpg     0
# 1       0_1.jpg     0
# 2      0_10.jpg     0
# 3     0_100.jpg     0
# 4     0_101.jpg     0
# 5     0_102.jpg     0
# 6     0_103.jpg     0
# 7     0_104.jpg     0
# 8     0_105.jpg     0
# 9     0_106.jpg     0
# 10    0_107.jpg     0
# 11    0_108.jpg     0
# 12    0_109.jpg     0
# 13     0_11.jpg     0
# 14    0_110.jpg     0
# 15    0_111.jpg     0
# 16    0_112.jpg     0
# 17    0_113.jpg     0
# 18    0_114.jpg     0
# 19    0_115.jpg     0
# 20    0_116.jpg     0
# 21    0_117.jpg     0
# 22    0_118.jpg     0
# 23    0_119.jpg     0
# 24     0_12.jpg     0
# 25    0_120.jpg     0
# 26    0_121.jpg     0
# 27    0_122.jpg     0
# 28    0_123.jpg     0
# 29    0_124.jpg     0
# ...         ...   ...
# 9836  9_972.jpg     9
# 9837  9_973.jpg     9
# 9838  9_974.jpg     9
# 9839  9_975.jpg     9
# 9840  9_976.jpg     9
# 9841  9_977.jpg     9
# 9842  9_978.jpg     9
# 9843  9_979.jpg     9
# 9844   9_98.jpg     9
# ...

# %%
import matplotlib
matplotlib.use("Agg")
import keras.applications
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet152
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from sklearn.metrics import classification_report
import numpy as np
import pickle
import os
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print(dir(keras.applications))
BATCH_SIZE = 32
MODEL_PATH = os.path.sep.join(["output", "food11.model"])
UNFROZEN_PLOT_PATH = os.path.sep.join(["output", "unfrozen.png"])
WARMUP_PLOT_PATH = os.path.sep.join(["output", "warmup.png"])

def plot_training(H, N, plotPath):
# construct a plot that plots and saves the training history
    plt.style.use("ggplot")
    plt.figure()
    plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
    plt.plot(np.arange(0, N), H.history["acc"], label="train_acc")
    plt.plot(np.arange(0, N), H.history["val_acc"], label="val_acc")
    plt.title("Training Loss and Accuracy")
    plt.xlabel("Epoch #")
    plt.ylabel("Loss/Accuracy")
    plt.legend(loc="lower left")
    plt.savefig(plotPath)

trainAug = ImageDataGenerator(rotation_range=30,zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15,horizontal_flip=True,fill_mode="nearest")
valAug = ImageDataGenerator()
mean = np.array([123.68, 116.779, 103.939], dtype="float32")
trainAug.mean = mean
valAug.mean = mean



# initialize the training generator
trainGen = trainAug.flow_from_dataframe(
    dataframe = dataframe_train,
    directory = pp+"\\data\\training",
    x_col = "filename",
    y_col = "label",
    class_mode="categorical",
    target_size=(224, 224),
    color_mode="rgb",
    shuffle=True,batch_size=32)

# initialize the validation generator
valGen = valAug.flow_from_dataframe(
    dataframe = dataframe_train,
    directory = pp+"\\data\\validation",
    x_col = "filename",
    y_col = "label",
    class_mode="categorical",
    target_size=(224, 224),
    color_mode="rgb",
    shuffle=False,batch_size=32)

# initialize the testing generator
testGen = valAug.flow_from_dataframe(
    dataframe = dataframe_train,
    directory = pp+"\\data\\kaggle_evaluation",
    x_col = "filename",
    y_col = "label",
    class_mode="categorical",
    target_size=(224, 224),
    color_mode="rgb",
    shuffle=False,batch_size=32)
# Out:
# Using TensorFlow backend.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9176056656630047393
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6584097178
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15903710283560046909
# physical_device_desc: "device: 0, name: GeForce RTX 2080, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]
# ...

# %%
baseModel = ResNet152(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))
 
# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(11, activation="softmax")(headModel)
 
# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)


# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in baseModel.layers:
    layer.trainable = False

# %%
print("[INFO] compiling model...")
opt = SGD(lr=1e-4, momentum=0.9,decay=1e-4)
model.compile(loss="categorical_crossentropy", optimizer=opt,
    metrics=["accuracy"])

print("[INFO] training head...")
H = model.fit_generator(
    trainGen,
    steps_per_epoch=np.ceil(9866/32) ,
    validation_data=valGen,
    validation_steps=np.ceil(3430/32) ,
    epochs=50)
model.save("food11Inception152")
# Out:
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/50
# ...

# %%
print("[INFO] evaluating after fine-tuning network head...")
model.save("Resnet152")
dataframe_eval = pd.DataFrame(kaggle_evaluation)
dataframe_eval.columns = ["filename"]
testGen = valAug.flow_from_dataframe(
    dataframe = dataframe_train,
    directory = pp+"\\data\\kaggle_evaluation",
    x_col = "filename",
    class_mode="categorical",
    target_size=(224, 224),
    color_mode="rgb",
    shuffle=False,batch_size=32)

testGen.reset()
predIdxs = model.predict_generator(testGen,
    steps=(np.ceil(3347/32) + 1)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(testGen.classes, predIdxs,
    target_names=testGen.class_indices.keys()))
plot_training(H, 50, config.WARMUP_PLOT_PATH)
